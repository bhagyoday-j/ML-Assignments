# %%
import matplotlib.pyplot as plt 
import numpy as np 

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints, color = "green", marker = "o")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.title("My first graph!")
plt.show()

# %%
students = np.array(['A', 'B', 'C', 'D'])
marks = np.array([90, 80, 70, 60])

plt.bar(students, marks, color = "yellow")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks of students")
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,7,8,7,6]

plt.scatter(x,y)
plt.show()

# %%
labels = ["A", "B", "C"]
sizes = [40, 35, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y1 = [10,20,25,30]
y2 = [5,15,20,25]

plt.subplot(1,2,1)
plt.plot(x,y1)
plt.title("First Plot")

plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title("Second Plot")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

ax.scatter(x,y,z)

plt.show()

# %%
fig = plt.subplot(1, 1, 1, projection='3d')

print(fig)
# Out:
# Axes3D(0.125,0.11;0.775x0.77)

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = '*')
plt.show()

# %%
# marker|line|color => o:r => o meance marker, : meance line, and r meance red color
# -, --, -., : => line styles
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o:k')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o-g')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o--m')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o-.c')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dotted', marker = 'o', color = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dashed', marker = 'o', color = 'k')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
# ls is short for linestyle
plt.plot(ypoints, ls = ':', marker = 'o', color = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dotted', marker = 'o', color = 'r', linewidth = 20.5, markersize = 10)
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
y3 = np.array([5, 7, 9, 12])

plt.plot(y1)
plt.plot(y2)
plt.plot(y3)

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid()
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) # 1 row, 2 columns, 1st plot
plt.plot(x, y)

#plot 2:
x2 = np.array([0, 1, 2, 3])
y2 = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2) # 1 row, 2 columns, 2nd plot
plt.plot(x2, y2)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x, y)

#plot 2:
x2 = np.array([0, 1, 2, 3])
y2 = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2) 
plt.plot(x2, y2)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1) 
plt.plot(x, y)

#plot 2:
x2 = np.array([0, 1, 2, 3])
y2 = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x2, y2)
plt.show()

# %%
# 6 plots
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.title("Plot 1")
plt.plot(x, y)

x1 = np.array([0, 1, 2, 3])
y1 = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.title("Plot 2")
plt.plot(x1, y1)

x2 = np.array([0, 1, 2, 3])
y2 = np.array([5, 15, 25, 35])
plt.subplot(2, 3, 3)
plt.title("Plot 3")
plt.plot(x2, y2)

x3 = np.array([0, 1, 2, 3])
y3 = np.array([2, 4, 6, 8])
plt.subplot(2, 3, 4)
plt.title("Plot 4")
plt.plot(x3, y3)  

# x4 = np.array([0, 1, 2, 3])
# y4 = np.array([1, 3, 5, 7])
# plt.subplot(2, 3, 5)
# plt.title("Plot 5") 
# plt.plot(x4, y4)

x5 = np.array([0, 1, 2, 3])
y5 = np.array([0, 2, 4, 6])
plt.subplot(2, 3, 6)
plt.title("Plot 6")
plt.plot(x5, y5)

plt.suptitle("6 Subplots")
plt.show()
